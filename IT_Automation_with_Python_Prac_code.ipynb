# %% [markdown]
# <a href="https://colab.research.google.com/github/Er-AI-GK/Leet_code/blob/main/IT_Automation_with_Python_Prac_code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Finding Area of Shapes || Python Program**
#
# ---

# %% [markdown]
# ### **Area of Triangle**
# ![image.png](data:image/png;base64,...)

# %%
base = 5
height = 3
area = (base*height)/2

print("Area of Triangle : ",area)
# Out:
# Area of Triangle :  7.5

# %% [markdown]
# ### **Area of Rectangle**
# ![image.png](data:image/png;base64,...)

# %%
length = 10
width  = 2
area = (length*width)

print("Area of Rectangle : ",area)
# Out:
# Area of Rectangle :  20

# %% [markdown]
# ### **Area of Square**
# ![image.png](data:image/png;base64,...)

# %%
length = 10
area = length**2
print("Area of Square : ",area)
# Out:
# Area of Square :  100

# %% [markdown]
# ###**Area of Circle**
# ![image.png](data:image/png;base64,...)

# %%
radius = 4
area = 3.14 * radius**2
print("Area of Circle : ",area)
# Out:
# Area of Circle :  50.24

# %% [markdown]
# ###**Area of Parallelogram**
# ![image.png](data:image/png;base64,...)

# %%
base = 7
height = 4
area = base*height
print("Area of Parallelogram : ",area)
# Out:
# Area of Parallelogram :  28

# %% [markdown]
# ###**Area of Rhoumbus**
#
# ![image.png](data:image/png;base64,...)
